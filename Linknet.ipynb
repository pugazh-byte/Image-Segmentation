# %%
import csv
import json
import os
from PIL import Image

import pprint
import re
import copy

import skimage.draw

import visualize
import utils as my_utils

import matplotlib.pyplot as plt
import cv2

import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from IPython.display import clear_output

# %%
# Out:
# Requirement already satisfied: tensorflow in c:\users\pugazharasu\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.20.1)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pugazharasu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\pugazharasu\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\pugazharasu\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pugazharasu\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pugazharasu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pugazharasu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\pugazharasu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pugazharasu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pugazharasu\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Data structures

# %%
# global context variables
segmentation_path = './data/segmentation_masks' # a folder of annotation files
img_path = './data/images' # a folder of image files

# %%
class img_meta:
    # img_name: image file name
    # annotations: the annotation list
    
    def __str__(self):
        return 'img_name: ' + self.img_name +  ', mask_name: \n' + self.mask_name
    def __repr__(self):
        return 'img_name: ' + self.img_name +  ', mask_name: \n' + self.mask_name
    
    def process(self, img_name, segmentation_path):
        
        self.img_name = img_name
        
        img_tokens = img_name.strip('.png')
        img_tokens = img_tokens.split('_')
        
        img_key = img_tokens[0]
        img_name_key = img_tokens[1]
        
#         print(f"Image name_key: {img_name_key}")
#         print(f"Image key: {img_key}")
        
        # Check all segmentation masks
        mask_files = os.listdir(segmentation_path)
        
        for file in mask_files:
            
            file_copy = copy.deepcopy(file)
            file_copy = re.sub(r"\.[0-9]", "", file_copy)
            
            mask_tokens = file_copy.split('_')
            mask_name_key = mask_tokens[0]
            
            for token in mask_tokens:
                if len(token)<=2:
                    mask_key = token
                    break
            
#             print("Mask Key: ", mask_key)
            if img_key == mask_key:
                self.mask_name = file
                break


    
    #This function uses opencv rather than PIL to load image.

    def load_image(self):
        
        img_file_path = os.path.join(img_path, self.img_name)
        
        """Load the specified image and return a [H,W,3] Numpy array.
        """
        # Load image
        image = cv2.imread(img_file_path)
        # If grayscale. Convert to RGB for consistency.
        if image.ndim != 3:
            image = skimage.color.gray2rgb(image)
        # If has an alpha channel, remove it for consistency
        if image.shape[-1] == 4:
            image = image[..., :3]

        return image
    
    def load_mask(self):
        mask_file_path = os.path.join(segmentation_path, self.mask_name)
        
        # Load mask
        mask = cv2.imread(mask_file_path, cv2.IMREAD_GRAYSCALE)
        # Normalize mask between (0-1)
        mask = np.where(mask>0, 1, 0)

        return mask

# %% [markdown]
# # Parse all image files

# %%
img_metas = []

for file in os.listdir(img_path):
    if file.endswith('.png'):
        print('Processing', file, '...')
        img_meta_obj = img_meta()
        img_meta_obj.process(file, segmentation_path)
        img_metas.append(img_meta_obj)
    else:
        print('[WARNING] Non-image file detected:', file)
# Out:
# Processing 10_bachamollaharshavardhanreddy.png ...
# Processing 10_kanugovimahidhar.png ...
# Processing 10_rabbyshahariar.png ...
# Processing 11_bachamollaharshavardhanreddy.png ...
# Processing 11_karnasaimanishreddy.png ...
# Processing 11_rabbyshahariar.png ...
# Processing 11_rajakvarunraju.png ...
# Processing 12_keshidianudeep.png ...
# Processing 12_rajakvarunraju.png ...
# Processing 13_kollasaividwan.png ...
# Processing 14_kongarachanikya.png ...
# Processing 15_bonuvarshinireddy.png ...
# Processing 15_rayallavineethabhavya.png ...
# Processing 16_bonuvarshinireddy.png ...
# Processing 16_rayallavineethabhavya.png ...
# Processing 17_lakkireddybrunda.png ...
# Processing 17_runjalasunithaglory.png ...
# Processing 18_bungmahesh.png ...
# Processing 18_runjalasunithaglory.png ...
# Processing 18_sahapratim.png ...
# Processing 19_bungmahesh.png ...
# Processing 19_sahapratim.png ...
# Processing 1_adhikarisaugat.png ...
# Processing 1_ahsanmuhammad.png ...
# Processing 1_pandirinikhilkumar.png ...
# Processing 20_chaudharyamitlakshmikant.png ...
# Processing 20_lewisseth.png ...
# Processing 20_seelamsumanthkumarreddy.png ...
# Processing 21_chaudharyamitlakshmikant.png ...
# Processing 21_cheniminenihemanthi.png ...
# Processing 21_seelamsumanthkumarreddy.png ...
# Processing 21_shakerbilawal.png ...
# Processing 22_cheniminenihemanthi.png ...
# Processing 22_shakerbilawal.png ...
# Processing 23_chikkalasaikiran.png ...
# Processing 24_chikkalasaikiran.png ...
# Processing 24_chintamvamsikrishna.png ...
# Processing 25_chintamvamsikrishna.png ...
# Processing 26_dantuluripretham.png ...
# Processing 27_dantuluripretham.png ...
# Processing 27_dasarkadeep.png ...
# Processing 28_dasarkadeep.png ...
# Processing 2_ahsanmuhammad.png ...
# Processing 2_akulasaisanjay.png ...
# Processing 30_divvelapraveen.png ...
# Processing 33_duddukurileelakrishna.png ...
# Processing 33_valasanivenugopal.png ...
# Processing 34_duddukurileelakrishna.png ...
# Processing 34_dykenlandon.png ...
# Processing 34_valasanivenugopal.png ...
# Processing 35_dykenlandon.png ...
# Processing 36_gajamcharantej.png ...
# Processing 36_vodapallikalyani.png ...
# Processing 38_gorantlasaikrishnavarma.png ...
# Processing 38_wadoodhamid.png ...
# Processing 39_gorantlasaikrishnavarma.png ...
# Processing 39_goturisaikarthikreddy.png ...
# Processing 3_akulasaisanjay.png ...
# Processing 3_anandankit.png ...
# Processing 40_goturisaikarthikreddy.png ...
# Processing 41_olajideemmanuelolamide.png ...
# Processing 42_gundebommualekhya.png ...
# Processing 43_gundebommualekhya.png ...
# Processing 43_gundlapallybhanuteja.png ...
# Processing 43_pagarepranav.png ...
# Processing 44_gundlapallybhanuteja.png ...
# Processing 44_guragainbijay.png ...
# Processing 45_guragainbijay.png ...
# Processing 46_pampanaaditya.png ...
# Processing 47_indukurisubhavarshitha.png ...
# Processing 47_panchalsagarlaxmikant.png ...
# Processing 48_adhikarisaugat.png ...
# Processing 48_indukurisubhavarshitha.png ...
# Processing 48_pandirinikhilkumar.png ...
# Processing 49_ahsanmuhammad.png ...
# Processing 4_anandankit.png ...
# Processing 4_patipravasini.png ...
# Processing 50_akulasaisanjay.png ...
# Processing 51_anandankit.png ...
# Processing 52_jammulavathsal.png ...
# Processing 52_patipravasini.png ...
# Processing 53_jammulavathsal.png ...
# Processing 53_junnuthulapranayreddy.png ...
# Processing 53_peddinenigowtham.png ...
# Processing 55_atlachandrasekharreddy.png ...
# Processing 57_kanugovimahidhar.png ...
# Processing 58_bachamollaharshavardhanreddy.png ...
# Processing 58_kanugovimahidhar.png ...
# Processing 58_karnasaimanishreddy.png ...
# Processing 58_rabbyshahariar.png ...
# Processing 59_karnasaimanishreddy.png ...
# Processing 59_keshidianudeep.png ...
# Processing 59_rajakvarunraju.png ...
# Processing 5_jammulavathsal.png ...
# Processing 5_patipravasini.png ...
# Processing 5_peddinenigowtham.png ...
# Processing 60_keshidianudeep.png ...
# Processing 60_kollasaividwan.png ...
# Processing 61_kollasaividwan.png ...
# Processing 61_kongarachanikya.png ...
# Processing 62_kongarachanikya.png ...
# Processing 63_bonuvarshinireddy.png ...
# Processing 63_rayallavineethabhavya.png ...
# Processing 64_lakkireddybrunda.png ...
# Processing 65_lakkireddybrunda.png ...
# Processing 65_runjalasunithaglory.png ...
# Processing 66_bungmahesh.png ...
# Processing 66_sahapratim.png ...
# Processing 67_lewisseth.png ...
# Processing 68_chaudharyamitlakshmikant.png ...
# Processing 68_lewisseth.png ...
# Processing 68_lokahrishikeshreddy.png ...
# Processing 68_seelamsumanthkumarreddy.png ...
# Processing 69_cheniminenihemanthi.png ...
# Processing 69_lokahrishikeshreddy.png ...
# Processing 69_shakerbilawal.png ...
# Processing 6_anwarmuhammadjunaid.png ...
# Processing 6_junnuthulapranayreddy.png ...
# Processing 6_peddinenigowtham.png ...
# Processing 71_chikkalasaikiran.png ...
# Processing 72_chintamvamsikrishna.png ...
# Processing 74_dantuluripretham.png ...
# Processing 74_mallempallicharankumar.png ...
# Processing 75_mallempallicharankumar.png ...
# Processing 76_dayanasri.png ...
# Processing 7_anwarmuhammadjunaid.png ...
# Processing 7_atlachandrasekharreddy.png ...
# Processing 81_duddukurileelakrishna.png ...
# Processing 81_valasanivenugopal.png ...
# Processing 82_dykenlandon.png ...
# Processing 83_nadimpallisriramakesavaakhilvarma.png ...
# Processing 84_gajamcharantej.png ...
# Processing 84_vodapallikalyani.png ...
# Processing 85_wadoodhamid.png ...
# Processing 86_gorantlasaikrishnavarma.png ...
# Processing 87_goturisaikarthikreddy.png ...
# Processing 88_oladriarchana.png ...
# Processing 88_olajideemmanuelolamide.png ...
# Processing 89_olajideemmanuelolamide.png ...
# Processing 8_atlachandrasekharreddy.png ...
# Processing 90_gundebommualekhya.png ...
# Processing 90_pagarepranav.png ...
# Processing 91_gundlapallybhanuteja.png ...
# Processing 91_pagarepranav.png ...
# Processing 92_guragainbijay.png ...
# Processing 93_pampanaaditya.png ...
# Processing 94_pampanaaditya.png ...
# Processing 95_adhikarisaugat.png ...
# Processing 95_indukurisubhavarshitha.png ...
# Processing 95_pandirinikhilkumar.png ...

# %% [markdown]
# ### Check one object

# %%
print(len(img_metas))

img_meta_obj = img_metas[1]
print(img_meta_obj)
# Out:
# 150
# img_name: 10_kanugovimahidhar.png, mask_name:
# bachamollaharshavardhanreddy_6011154_67421512_10_segment_mask.png

# %% [markdown]
# ### Load an image

# %%
img_obj = img_meta_obj.load_image()
print(img_obj.shape)
visualize.display_images([img_obj])
# Out:
# (387, 368, 3)

# %% [markdown]
# # Visualize image with mask

# %%
# Visualize a random file

colors = visualize.random_colors(5)
color = colors[0]

#sample_idx = np.random.choice(len(img_metas))
sample_idx = 1
print("Sample Index: ", sample_idx)

#Image Meta Data
img_meta_obj = img_metas[sample_idx]

img_file = img_meta_obj.load_image()
print("Image shape: ", img_file.shape)

mask = img_meta_obj.load_mask()

print("Mask shape: ", mask.shape)
# Out:
# Sample Index:  1
# Image shape:  (387, 368, 3)
# Mask shape:  (387, 368)

# %%
masked_image = visualize.apply_mask(img_file, mask, color)
visualize.display_images([masked_image])

# %% [markdown]
# # U-Net demo

# %% [markdown]
# ### Data processing

# %%
# Image size that we are going to use
IMG_SIZE = 256
# Our images are RGB (3 channels)
N_CHANNELS = 3
# Foreground and backgroung
N_CLASSES = 2

# %%
#Loads the data and creates a tuple of images
#masks to be later made into Tensorflow data object

def dataLoader():
    img_list = []
    mask_list = []
    
    
    for i in range(len(img_metas)):
        
        img_meta_obj = img_metas[i]
        
        img_file = img_meta_obj.load_image()
        #print("Image shape: ", img_file.shape)
        
        #Convert mask to the shape of an image (3D) with channel=1
        mask = img_meta_obj.load_mask()
        mask = np.expand_dims(mask, axis =-1)

        
        #Rezize mask and image to common size
        # Resize Image to 256x256
        img_file, _, scale, padding,_ = my_utils.resize_image(img_file, max_dim = IMG_SIZE, mode="square")
        #print("Image shape: ", img_file.shape)
        # Resize Mask to 256x256
        mask = my_utils.resize_mask(mask, scale, padding)
        #Fix Overlap bug
        mask = np.where(mask > 0, 1, 0)
        mask = mask.astype(np.float32)
        #print(np.amax(mask))
        #print("Mask shape: ", mask.shape)
        
        #Normalize Image
        img_file = img_file.astype(np.float32)
        img_file = img_file/255.0
        #print("Image shape: ", img_file.shape)
        

        img_list.append(img_file)
        mask_list.append(mask)

    return (img_list, mask_list)

# %% [markdown]
# ### Create Tensorflow Data Loader

# %%
dataset = tf.data.Dataset.from_tensor_slices(dataLoader())

# %% [markdown]
# #### Train/Validation Split

# %%
train_size = int(0.9 * len(img_metas))
val_size = int(0.1 * len(img_metas))

train_dataset = dataset.take(train_size)
val_dataset = dataset.skip(train_size)

# %% [markdown]
# # Training

# %% [markdown]
# ## The following training code and model code was adapted from
# ### https://github.com/bnsreenu/python_for_microscopists/blob/master/211_multiclass_Unet_vs_linknet.py

# %% [markdown]
# #### Data Tuning Parameters

# %%
BATCH_SIZE = 5
BUFFER_SIZE = 1000
# important for reproducibility
# this allows to generate the same random numbers
SEED = 42
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
dataset = {"train": train_dataset, "val": val_dataset}

# -- Train Dataset --#
#dataset['train'] = dataset['train'].shuffle(buffer_size=BUFFER_SIZE, seed=SEED)
dataset['train'] = dataset['train'].repeat()
dataset['train'] = dataset['train'].batch(BATCH_SIZE)
dataset['train'] = dataset['train'].prefetch(buffer_size=AUTOTUNE)

#-- Validation Dataset --#
dataset['val'] = dataset['val'].repeat()
dataset['val'] = dataset['val'].batch(BATCH_SIZE)
dataset['val'] = dataset['val'].prefetch(buffer_size=AUTOTUNE)

print(dataset['train'])
print(dataset['val'])

# how shuffle works: https://stackoverflow.com/a/53517848
# Out:
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.float32)>
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.float32)>

# %%
def display_sample(display_list):
    """Show side-by-side an input image,
    the ground truth and the prediction.
    """
    plt.figure(figsize=(18, 18))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
for image, mask in dataset['train'].take(1):
    sample_image, sample_mask = image, mask
    

display_sample([sample_image[1], sample_mask[1]])

# %%
## https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/models/linknet.py

# %%
BACKBONE1 = 'resnet34'
import segmentation_models as sm

sm.set_framework('tf.keras')

sm.framework()
preprocess_input1 = sm.get_preprocessing(BACKBONE1)

# %%
X_train1 = preprocess_input1(dataset['train'])
X_test1 = preprocess_input1(dataset['val'])

# %%
activation='softmax'

model2 = sm.Linknet(BACKBONE1, encoder_weights='imagenet', classes=N_CLASSES, activation=activation)
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85524480/85521592 [==============================] - 4s 0us/step
# 85532672/85521592 [==============================] - 4s 0us/step

# %%
def dice_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.math.sigmoid(y_pred)
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)
    return 1 - numerator / denominator

# %%
##model2.compile(optim, total_loss, metrics=metrics)

model2.compile(optimizer = Adam(learning_rate=0.0001), 
              loss = dice_loss,
              metrics=['accuracy'])

# %%
print(model2.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, None, None,  0           []
#                                  3)]
#
#  bn_data (BatchNormalization)   (None, None, None,   9           ['data[0][0]']
#                                 3)
#
#  zero_padding2d_68 (ZeroPadding  (None, None, None,   0          ['bn_data[0][0]']
#  2D)                            3)
#
#  conv0 (Conv2D)                 (None, None, None,   9408        ['zero_padding2d_68[0][0]']
#                                 64)
#
#  bn0 (BatchNormalization)       (None, None, None,   256         ['conv0[0][0]']
#                                 64)
#
#  relu0 (Activation)             (None, None, None,   0           ['bn0[0][0]']
#                                 64)
#
#  zero_padding2d_69 (ZeroPadding  (None, None, None,   0          ['relu0[0][0]']
#  2D)                            64)
#
#  pooling0 (MaxPooling2D)        (None, None, None,   0           ['zero_padding2d_69[0][0]']
#                                 64)
#
#  stage1_unit1_bn1 (BatchNormali  (None, None, None,   256        ['pooling0[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu1 (Activation  (None, None, None,   0          ['stage1_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_70 (ZeroPadding  (None, None, None,   0          ['stage1_unit1_relu1[0][0]']
#  2D)                            64)
#
#  stage1_unit1_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_70[0][0]']
#                                 64)
#
#  stage1_unit1_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit1_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu2 (Activation  (None, None, None,   0          ['stage1_unit1_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_71 (ZeroPadding  (None, None, None,   0          ['stage1_unit1_relu2[0][0]']
#  2D)                            64)
#
#  stage1_unit1_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_71[0][0]']
#                                 64)
#
#  stage1_unit1_sc (Conv2D)       (None, None, None,   4096        ['stage1_unit1_relu1[0][0]']
#                                 64)
#
#  add_32 (Add)                   (None, None, None,   0           ['stage1_unit1_conv2[0][0]',
#                                 64)                               'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, None, None,   256        ['add_32[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu1 (Activation  (None, None, None,   0          ['stage1_unit2_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_72 (ZeroPadding  (None, None, None,   0          ['stage1_unit2_relu1[0][0]']
#  2D)                            64)
#
#  stage1_unit2_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_72[0][0]']
#                                 64)
#
#  stage1_unit2_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit2_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu2 (Activation  (None, None, None,   0          ['stage1_unit2_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_73 (ZeroPadding  (None, None, None,   0          ['stage1_unit2_relu2[0][0]']
#  2D)                            64)
#
#  stage1_unit2_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_73[0][0]']
#                                 64)
#
#  add_33 (Add)                   (None, None, None,   0           ['stage1_unit2_conv2[0][0]',
#                                 64)                               'add_32[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, None, None,   256        ['add_33[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu1 (Activation  (None, None, None,   0          ['stage1_unit3_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_74 (ZeroPadding  (None, None, None,   0          ['stage1_unit3_relu1[0][0]']
#  2D)                            64)
#
#  stage1_unit3_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_74[0][0]']
#                                 64)
#
#  stage1_unit3_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit3_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu2 (Activation  (None, None, None,   0          ['stage1_unit3_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_75 (ZeroPadding  (None, None, None,   0          ['stage1_unit3_relu2[0][0]']
#  2D)                            64)
#
#  stage1_unit3_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_75[0][0]']
#                                 64)
#
#  add_34 (Add)                   (None, None, None,   0           ['stage1_unit3_conv2[0][0]',
#                                 64)                               'add_33[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, None, None,   256        ['add_34[0][0]']
#  zation)                        64)
#
#  stage2_unit1_relu1 (Activation  (None, None, None,   0          ['stage2_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_76 (ZeroPadding  (None, None, None,   0          ['stage2_unit1_relu1[0][0]']
#  2D)                            64)
#
#  stage2_unit1_conv1 (Conv2D)    (None, None, None,   73728       ['zero_padding2d_76[0][0]']
#                                 128)
#
#  stage2_unit1_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit1_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit1_relu2 (Activation  (None, None, None,   0          ['stage2_unit1_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_77 (ZeroPadding  (None, None, None,   0          ['stage2_unit1_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit1_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_77[0][0]']
#                                 128)
#
#  stage2_unit1_sc (Conv2D)       (None, None, None,   8192        ['stage2_unit1_relu1[0][0]']
#                                 128)
#
#  add_35 (Add)                   (None, None, None,   0           ['stage2_unit1_conv2[0][0]',
#                                 128)                              'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, None, None,   512        ['add_35[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu1 (Activation  (None, None, None,   0          ['stage2_unit2_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_78 (ZeroPadding  (None, None, None,   0          ['stage2_unit2_relu1[0][0]']
#  2D)                            128)
#
#  stage2_unit2_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_78[0][0]']
#                                 128)
#
#  stage2_unit2_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit2_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu2 (Activation  (None, None, None,   0          ['stage2_unit2_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_79 (ZeroPadding  (None, None, None,   0          ['stage2_unit2_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit2_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_79[0][0]']
#                                 128)
#
#  add_36 (Add)                   (None, None, None,   0           ['stage2_unit2_conv2[0][0]',
#                                 128)                              'add_35[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, None, None,   512        ['add_36[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu1 (Activation  (None, None, None,   0          ['stage2_unit3_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_80 (ZeroPadding  (None, None, None,   0          ['stage2_unit3_relu1[0][0]']
#  2D)                            128)
#
#  stage2_unit3_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_80[0][0]']
#                                 128)
#
#  stage2_unit3_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit3_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu2 (Activation  (None, None, None,   0          ['stage2_unit3_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_81 (ZeroPadding  (None, None, None,   0          ['stage2_unit3_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit3_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_81[0][0]']
#                                 128)
#
#  add_37 (Add)                   (None, None, None,   0           ['stage2_unit3_conv2[0][0]',
#                                 128)                              'add_36[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, None, None,   512        ['add_37[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu1 (Activation  (None, None, None,   0          ['stage2_unit4_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_82 (ZeroPadding  (None, None, None,   0          ['stage2_unit4_relu1[0][0]']
#  2D)                            128)
#
#  stage2_unit4_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_82[0][0]']
#                                 128)
#
#  stage2_unit4_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit4_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu2 (Activation  (None, None, None,   0          ['stage2_unit4_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_83 (ZeroPadding  (None, None, None,   0          ['stage2_unit4_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit4_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_83[0][0]']
#                                 128)
#
#  add_38 (Add)                   (None, None, None,   0           ['stage2_unit4_conv2[0][0]',
#                                 128)                              'add_37[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, None, None,   512        ['add_38[0][0]']
#  zation)                        128)
#
#  stage3_unit1_relu1 (Activation  (None, None, None,   0          ['stage3_unit1_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_84 (ZeroPadding  (None, None, None,   0          ['stage3_unit1_relu1[0][0]']
#  2D)                            128)
#
#  stage3_unit1_conv1 (Conv2D)    (None, None, None,   294912      ['zero_padding2d_84[0][0]']
#                                 256)
#
#  stage3_unit1_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit1_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit1_relu2 (Activation  (None, None, None,   0          ['stage3_unit1_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_85 (ZeroPadding  (None, None, None,   0          ['stage3_unit1_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit1_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_85[0][0]']
#                                 256)
#
#  stage3_unit1_sc (Conv2D)       (None, None, None,   32768       ['stage3_unit1_relu1[0][0]']
#                                 256)
#
#  add_39 (Add)                   (None, None, None,   0           ['stage3_unit1_conv2[0][0]',
#                                 256)                              'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, None, None,   1024       ['add_39[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu1 (Activation  (None, None, None,   0          ['stage3_unit2_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_86 (ZeroPadding  (None, None, None,   0          ['stage3_unit2_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit2_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_86[0][0]']
#                                 256)
#
#  stage3_unit2_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit2_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu2 (Activation  (None, None, None,   0          ['stage3_unit2_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_87 (ZeroPadding  (None, None, None,   0          ['stage3_unit2_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit2_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_87[0][0]']
#                                 256)
#
#  add_40 (Add)                   (None, None, None,   0           ['stage3_unit2_conv2[0][0]',
#                                 256)                              'add_39[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, None, None,   1024       ['add_40[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu1 (Activation  (None, None, None,   0          ['stage3_unit3_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_88 (ZeroPadding  (None, None, None,   0          ['stage3_unit3_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit3_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_88[0][0]']
#                                 256)
#
#  stage3_unit3_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit3_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu2 (Activation  (None, None, None,   0          ['stage3_unit3_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_89 (ZeroPadding  (None, None, None,   0          ['stage3_unit3_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit3_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_89[0][0]']
#                                 256)
#
#  add_41 (Add)                   (None, None, None,   0           ['stage3_unit3_conv2[0][0]',
#                                 256)                              'add_40[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, None, None,   1024       ['add_41[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu1 (Activation  (None, None, None,   0          ['stage3_unit4_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_90 (ZeroPadding  (None, None, None,   0          ['stage3_unit4_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit4_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_90[0][0]']
#                                 256)
#
#  stage3_unit4_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit4_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu2 (Activation  (None, None, None,   0          ['stage3_unit4_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_91 (ZeroPadding  (None, None, None,   0          ['stage3_unit4_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit4_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_91[0][0]']
#                                 256)
#
#  add_42 (Add)                   (None, None, None,   0           ['stage3_unit4_conv2[0][0]',
#                                 256)                              'add_41[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, None, None,   1024       ['add_42[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu1 (Activation  (None, None, None,   0          ['stage3_unit5_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_92 (ZeroPadding  (None, None, None,   0          ['stage3_unit5_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit5_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_92[0][0]']
#                                 256)
#
#  stage3_unit5_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit5_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu2 (Activation  (None, None, None,   0          ['stage3_unit5_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_93 (ZeroPadding  (None, None, None,   0          ['stage3_unit5_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit5_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_93[0][0]']
#                                 256)
#
#  add_43 (Add)                   (None, None, None,   0           ['stage3_unit5_conv2[0][0]',
#                                 256)                              'add_42[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, None, None,   1024       ['add_43[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu1 (Activation  (None, None, None,   0          ['stage3_unit6_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_94 (ZeroPadding  (None, None, None,   0          ['stage3_unit6_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit6_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_94[0][0]']
#                                 256)
#
#  stage3_unit6_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit6_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu2 (Activation  (None, None, None,   0          ['stage3_unit6_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_95 (ZeroPadding  (None, None, None,   0          ['stage3_unit6_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit6_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_95[0][0]']
#                                 256)
#
#  add_44 (Add)                   (None, None, None,   0           ['stage3_unit6_conv2[0][0]',
#                                 256)                              'add_43[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, None, None,   1024       ['add_44[0][0]']
#  zation)                        256)
#
#  stage4_unit1_relu1 (Activation  (None, None, None,   0          ['stage4_unit1_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_96 (ZeroPadding  (None, None, None,   0          ['stage4_unit1_relu1[0][0]']
#  2D)                            256)
#
#  stage4_unit1_conv1 (Conv2D)    (None, None, None,   1179648     ['zero_padding2d_96[0][0]']
#                                 512)
#
#  stage4_unit1_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit1_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit1_relu2 (Activation  (None, None, None,   0          ['stage4_unit1_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_97 (ZeroPadding  (None, None, None,   0          ['stage4_unit1_relu2[0][0]']
#  2D)                            512)
#
#  stage4_unit1_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_97[0][0]']
#                                 512)
#
#  stage4_unit1_sc (Conv2D)       (None, None, None,   131072      ['stage4_unit1_relu1[0][0]']
#                                 512)
#
#  add_45 (Add)                   (None, None, None,   0           ['stage4_unit1_conv2[0][0]',
#                                 512)                              'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, None, None,   2048       ['add_45[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu1 (Activation  (None, None, None,   0          ['stage4_unit2_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_98 (ZeroPadding  (None, None, None,   0          ['stage4_unit2_relu1[0][0]']
#  2D)                            512)
#
#  stage4_unit2_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_98[0][0]']
#                                 512)
#
#  stage4_unit2_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit2_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu2 (Activation  (None, None, None,   0          ['stage4_unit2_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_99 (ZeroPadding  (None, None, None,   0          ['stage4_unit2_relu2[0][0]']
#  2D)                            512)
#
#  stage4_unit2_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_99[0][0]']
#                                 512)
#
#  add_46 (Add)                   (None, None, None,   0           ['stage4_unit2_conv2[0][0]',
#                                 512)                              'add_45[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, None, None,   2048       ['add_46[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu1 (Activation  (None, None, None,   0          ['stage4_unit3_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_100 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu1[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_100[0][0]']
#                                 512)
#
#  stage4_unit3_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit3_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu2 (Activation  (None, None, None,   0          ['stage4_unit3_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_101 (ZeroPaddin  (None, None, None,   0          ['stage4_unit3_relu2[0][0]']
#  g2D)                           512)
#
#  stage4_unit3_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_101[0][0]']
#                                 512)
#
#  add_47 (Add)                   (None, None, None,   0           ['stage4_unit3_conv2[0][0]',
#                                 512)                              'add_46[0][0]']
#
#  bn1 (BatchNormalization)       (None, None, None,   2048        ['add_47[0][0]']
#                                 512)
#
#  relu1 (Activation)             (None, None, None,   0           ['bn1[0][0]']
#                                 512)
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   65536       ['relu1[0][0]']
#                                 128)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage0a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
# ...
#  ampling2D)                     128)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage0_upsampling[0][0]
#                                 128)                             ']
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage0b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage0c_conv (Conv2D)  (None, None, None,   32768       ['decoder_stage0b_relu[0][0]']
#                                 256)
#
#  decoder_stage0c_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0c_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0c_relu (Activati  (None, None, None,   0          ['decoder_stage0c_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0_add (Add)       (None, None, None,   0           ['decoder_stage0c_relu[0][0]',
#                                 256)                              'stage4_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   16384       ['decoder_stage0_add[0][0]']
#                                 64)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage1a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage1a_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage1_upsampling[0][0]
#                                 64)                              ']
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage1b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage1c_conv (Conv2D)  (None, None, None,   8192        ['decoder_stage1b_relu[0][0]']
#                                 128)
#
#  decoder_stage1c_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1c_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1c_relu (Activati  (None, None, None,   0          ['decoder_stage1c_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1_add (Add)       (None, None, None,   0           ['decoder_stage1c_relu[0][0]',
#                                 128)                              'stage3_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   4096        ['decoder_stage1_add[0][0]']
#                                 32)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage2a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage2a_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage2_upsampling[0][0]
#                                 32)                              ']
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage2b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage2c_conv (Conv2D)  (None, None, None,   2048        ['decoder_stage2b_relu[0][0]']
#                                 64)
#
#  decoder_stage2c_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2c_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2c_relu (Activati  (None, None, None,   0          ['decoder_stage2c_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2_add (Add)       (None, None, None,   0           ['decoder_stage2c_relu[0][0]',
#                                 64)                               'stage2_unit1_relu1[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   1024        ['decoder_stage2_add[0][0]']
#                                 16)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage3a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage3a_relu[0][0]']
#  ampling2D)                     16)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage3_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage3b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            16)
#
#  decoder_stage3c_conv (Conv2D)  (None, None, None,   1024        ['decoder_stage3b_relu[0][0]']
#                                 64)
#
#  decoder_stage3c_bn (BatchNorma  (None, None, None,   256        ['decoder_stage3c_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage3c_relu (Activati  (None, None, None,   0          ['decoder_stage3c_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_add (Add)       (None, None, None,   0           ['decoder_stage3c_relu[0][0]',
#                                 64)                               'relu0[0][0]']
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   1024        ['decoder_stage3_add[0][0]']
#                                 16)
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage4a_relu[0][0]']
#  ampling2D)                     16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4c_conv (Conv2D)  (None, None, None,   256         ['decoder_stage4b_relu[0][0]']
#                                 16)
#
#  decoder_stage4c_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4c_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4c_relu (Activati  (None, None, None,   0          ['decoder_stage4c_bn[0][0]']
#  on)                            16)
#
#  conv2d (Conv2D)                (None, None, None,   290         ['decoder_stage4c_relu[0][0]']
#                                 2)
#
#  softmax (Activation)           (None, None, None,   0           ['conv2d[0][0]']
#                                 2)
#
# ==================================================================================================
# Total params: 21,637,419
# Trainable params: 21,619,973
# Non-trainable params: 17,446
# __________________________________________________________________________________________________
# None

# %%
EPOCHS = 50

STEPS_PER_EPOCH = train_size // BATCH_SIZE
VALIDATION_STEPS = val_size // BATCH_SIZE

# %%
#This class will automatically save TF models
#at Epoch which are multiples of the SAVE_MULTIPLE parameter.
SAVE_MULTIPLE = 5

class ModelSaver(tf.keras.callbacks.Callback): 
    
    def on_epoch_end(self, epoch, logs={}):
        if (epoch)%SAVE_MULTIPLE == 0:  # Save when epochs are multiples of SAVE_MULTIPLE.
            self.model.save(f"./saved_models/model_{epoch}.h5")
# create and use callback:
saver = ModelSaver()

# %%
model2_history = model2.fit(dataset['train'], epochs=EPOCHS,
                          callbacks=[saver],
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=dataset['val'])
# Out:
# Epoch 1/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9526 - val_loss: 0.9616 - val_accuracy: 0.9763
# Epoch 2/50
# 27/27 [==============================] - 38s 1s/step - loss: 0.9468 - accuracy: 0.9571 - val_loss: 0.9616 - val_accuracy: 0.9763
# Epoch 3/50
# 27/27 [==============================] - 38s 1s/step - loss: 0.9468 - accuracy: 0.9606 - val_loss: 0.9616 - val_accuracy: 0.9763
# Epoch 4/50
# 27/27 [==============================] - 38s 1s/step - loss: 0.9468 - accuracy: 0.9628 - val_loss: 0.9616 - val_accuracy: 0.9763
# Epoch 5/50
# 27/27 [==============================] - 38s 1s/step - loss: 0.9468 - accuracy: 0.9643 - val_loss: 0.9616 - val_accuracy: 0.9763
# Epoch 6/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9654 - val_loss: 0.9616 - val_accuracy: 0.9763
# Epoch 7/50
# 27/27 [==============================] - 38s 1s/step - loss: 0.9468 - accuracy: 0.9663 - val_loss: 0.9616 - val_accuracy: 0.9764
# Epoch 8/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9667 - val_loss: 0.9616 - val_accuracy: 0.9765
# Epoch 9/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9671 - val_loss: 0.9616 - val_accuracy: 0.9766
# Epoch 10/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9675 - val_loss: 0.9616 - val_accuracy: 0.9767
# Epoch 11/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9679 - val_loss: 0.9616 - val_accuracy: 0.9768
# Epoch 12/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9684 - val_loss: 0.9616 - val_accuracy: 0.9767
# Epoch 13/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9688 - val_loss: 0.9616 - val_accuracy: 0.9767
# Epoch 14/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9690 - val_loss: 0.9616 - val_accuracy: 0.9766
# Epoch 15/50
# 27/27 [==============================] - 38s 1s/step - loss: 0.9468 - accuracy: 0.9693 - val_loss: 0.9616 - val_accuracy: 0.9765
# Epoch 16/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9468 - accuracy: 0.9695 - val_loss: 0.9616 - val_accuracy: 0.9764
# Epoch 17/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9468 - accuracy: 0.9698 - val_loss: 0.9616 - val_accuracy: 0.9764
# Epoch 18/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9699 - val_loss: 0.9616 - val_accuracy: 0.9764
# Epoch 19/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9701 - val_loss: 0.9616 - val_accuracy: 0.9764
# Epoch 20/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9703 - val_loss: 0.9616 - val_accuracy: 0.9765
# Epoch 21/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9705 - val_loss: 0.9616 - val_accuracy: 0.9765
# Epoch 22/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9707 - val_loss: 0.9615 - val_accuracy: 0.9766
# Epoch 23/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9708 - val_loss: 0.9615 - val_accuracy: 0.9767
# Epoch 24/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9711 - val_loss: 0.9615 - val_accuracy: 0.9771
# Epoch 25/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9714 - val_loss: 0.9615 - val_accuracy: 0.9773
# Epoch 26/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9715 - val_loss: 0.9614 - val_accuracy: 0.9776
# Epoch 27/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9717 - val_loss: 0.9614 - val_accuracy: 0.9779
# Epoch 28/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9719 - val_loss: 0.9614 - val_accuracy: 0.9782
# Epoch 29/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9720 - val_loss: 0.9614 - val_accuracy: 0.9784
# Epoch 30/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9722 - val_loss: 0.9613 - val_accuracy: 0.9785
# Epoch 31/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9724 - val_loss: 0.9613 - val_accuracy: 0.9787
# Epoch 32/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9727 - val_loss: 0.9613 - val_accuracy: 0.9786
# Epoch 33/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9728 - val_loss: 0.9613 - val_accuracy: 0.9785
# Epoch 34/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9729 - val_loss: 0.9613 - val_accuracy: 0.9786
# Epoch 35/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9730 - val_loss: 0.9613 - val_accuracy: 0.9786
# Epoch 36/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9734 - val_loss: 0.9613 - val_accuracy: 0.9785
# Epoch 37/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9735 - val_loss: 0.9613 - val_accuracy: 0.9785
# Epoch 38/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9737 - val_loss: 0.9613 - val_accuracy: 0.9787
# Epoch 39/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9739 - val_loss: 0.9613 - val_accuracy: 0.9787
# Epoch 40/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9738 - val_loss: 0.9612 - val_accuracy: 0.9785
# Epoch 41/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9741 - val_loss: 0.9612 - val_accuracy: 0.9786
# Epoch 42/50
# 27/27 [==============================] - 42s 2s/step - loss: 0.9467 - accuracy: 0.9743 - val_loss: 0.9612 - val_accuracy: 0.9785
# Epoch 43/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9745 - val_loss: 0.9612 - val_accuracy: 0.9788
# Epoch 44/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9746 - val_loss: 0.9612 - val_accuracy: 0.9787
# Epoch 45/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9747 - val_loss: 0.9612 - val_accuracy: 0.9789
# Epoch 46/50
# 27/27 [==============================] - 41s 2s/step - loss: 0.9467 - accuracy: 0.9748 - val_loss: 0.9612 - val_accuracy: 0.9794
# Epoch 47/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9750 - val_loss: 0.9612 - val_accuracy: 0.9794
# Epoch 48/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9751 - val_loss: 0.9612 - val_accuracy: 0.9794
# Epoch 49/50
# 27/27 [==============================] - 40s 1s/step - loss: 0.9467 - accuracy: 0.9751 - val_loss: 0.9612 - val_accuracy: 0.9795
# Epoch 50/50
# 27/27 [==============================] - 39s 1s/step - loss: 0.9467 - accuracy: 0.9752 - val_loss: 0.9612 - val_accuracy: 0.9792

# %% [markdown]
# #### Manually Save Model

# %%
## Save the model at the latest EPOCH or as desired
model2.save(f"./saved_models/model_{EPOCHS}.h5")

# %% [markdown]
# #### Load

# %% [markdown]
# # Process Prediction

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
#Pick first batch of Image from Validation set
for image, mask in dataset['val'].take(1):
    sample_image, sample_mask = image, mask

# %%
#Pick first Prediction Validation set
sample_idx = 2
pred_mask = model2.predict(sample_image)

sample_image = sample_image.numpy()[sample_idx] #Pick first image form a batch of 5
sample_image = (sample_image*255.0).astype(np.uint32)

#Ground Truth Mask
sample_mask = sample_mask.numpy()[sample_idx]
sample_mask = np.squeeze(sample_mask, axis =-1)

#Predicted Mask
pred_mask = pred_mask[sample_idx] #Pick first mask form a batch of 5

# %%
print(sample_image.shape)
print(pred_mask.shape)
# Out:
# (256, 256, 3)
# (256, 256, 2)

# %%
pred_mask = np.argmax(pred_mask, axis =-1)
#pred_mask = np.expand_dims(pred_mask, axis =-1)
print(sample_image.shape)
print(pred_mask.shape)
# Out:
# (256, 256, 3)
# (256, 256)

# %% [markdown]
# ### Visualize Prediction

# %%
colors = visualize.random_colors(10)
color = colors[0]
print(color)

masked_image = sample_image.astype(np.uint32).copy()
masked_image = visualize.apply_mask(masked_image, pred_mask, color)

visualize.display_images([masked_image])
# Out:
# (1.0, 0.0, 0.5999999999999996)

# %%
# Vizualize Ground Truth

# %%
#GT
colors = visualize.random_colors(10)
color = colors[0]
print(color)

masked_image = sample_image.astype(np.uint32).copy()

print(masked_image.shape)
print(sample_mask.shape)

masked_image = visualize.apply_mask(masked_image, sample_mask, color)

visualize.display_images([masked_image])
# Out:
# (1.0, 0.0, 0.5999999999999996)
# (256, 256, 3)
# (256, 256)

# %%
model2.save('linknet_res34_backbone_50epochs.hdf5')

# convert the history.history dict to a pandas DataFrame:     
hist2_df = pd.DataFrame(model2_history.history) 
hist2_csv_file = 'history_linknet.csv'
with open(hist2_csv_file, mode='w') as f:
    hist2_df.to_csv(f)

# %%
loss = model2_history.history['loss']
val_loss = model2_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
